# %% [markdown]
# # Evaluación 1 EUA
#
# ## Lucía Castañeda A01706644

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .xlsx sin indice
df= pd.read_csv('California_EUA.csv', encoding = "unicode_escape")
df
# Out:
#              ï»¿id                                      listing_url  \
# 0     9.580000e+02                 https://www.airbnb.com/rooms/958
# 1     5.858000e+03                https://www.airbnb.com/rooms/5858
# 2     8.142000e+03                https://www.airbnb.com/rooms/8142
# 3     8.339000e+03                https://www.airbnb.com/rooms/8339
# 4     8.739000e+03                https://www.airbnb.com/rooms/8739
# ...            ...                                              ...
# 6931  8.180000e+17  https://www.airbnb.com/rooms/818195233784141985
# 6932  8.180000e+17  https://www.airbnb.com/rooms/818231243893035313
# 6933  8.180000e+17  https://www.airbnb.com/rooms/818396267693629070
# 6934  8.180000e+17  https://www.airbnb.com/rooms/818474518435984613
# 6935  8.190000e+17  https://www.airbnb.com/rooms/818887060432463897
#
#          scrape_id last_scraped       source  \
# 0     2.020000e+13   06/03/2023  city scrape
# 1     2.020000e+13   06/03/2023  city scrape
# ...

# %%
#Reemplazamos valores nulos del dataframe con "bfill"
df1 =df.fillna(method="bfill") 
df1

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=df1.isnull().sum()
valores_nulos

# %%
#Reemplazamos valores nulos del dataframe con "mean"
#Realizamos una copia del dataframe
df2=df.copy()
df2=df2.fillna(round(df.mean(),1))
df2

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=df2.isnull().sum()
valores_nulos
# Out:
# ï»¿id                                           0
# listing_url                                     0
# scrape_id                                       0
# last_scraped                                    0
# source                                          0
#                                                ..
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# Length: 75, dtype: int64

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
df2.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=df2
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# <ipython-input-8-f35936a59650>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# <ipython-input-8-f35936a59650>:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# Limite superior permitido ï»¿id                                           1.054631e+18
# scrape_id                                       2.020000e+13
# host_id                                         5.371002e+08
# host_listings_count                             2.300397e+03
# ...

# %% [markdown]
# Se utilizó este método para eliminar valores atípicos debido a que es menos senisble y ayuda a mantener la forma general de los datos.

# %%
#Encontramos Ouliers del Dataframe
outliers= df2[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# <ipython-input-9-e84a43168787>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers= df2[(y>Limite_Superior)|(y<Limite_Inferior)]
#       ï»¿id listing_url  scrape_id last_scraped source name description  \
# 0       NaN         NaN        NaN          NaN    NaN  NaN         NaN
# 1       NaN         NaN        NaN          NaN    NaN  NaN         NaN
# 2       NaN         NaN        NaN          NaN    NaN  NaN         NaN
# 3       NaN         NaN        NaN          NaN    NaN  NaN         NaN
# 4       NaN         NaN        NaN          NaN    NaN  NaN         NaN
# ...     ...         ...        ...          ...    ...  ...         ...
# 6931    NaN         NaN        NaN          NaN    NaN  NaN         NaN
# 6932    NaN         NaN        NaN          NaN    NaN  NaN         NaN
# ...

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
df3= df2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
df3
# Out:
# <ipython-input-42-0ce5b7a1dcd6>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df3= df2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
#              ï»¿id listing_url     scrape_id last_scraped source name  \
# 0     9.580000e+02         NaN  2.020000e+13          NaN    NaN  NaN
# 1     5.858000e+03         NaN  2.020000e+13          NaN    NaN  NaN
# 2     8.142000e+03         NaN  2.020000e+13          NaN    NaN  NaN
# 3     8.339000e+03         NaN  2.020000e+13          NaN    NaN  NaN
# 4     8.739000e+03         NaN  2.020000e+13          NaN    NaN  NaN
# ...            ...         ...           ...          ...    ...  ...
# 6931  8.180000e+17         NaN  2.020000e+13          NaN    NaN  NaN
# 6932  8.180000e+17         NaN  2.020000e+13          NaN    NaN  NaN
# ...

# %%
#Eliminamos columnas innecesarias
df4= df3.drop(['listing_url','last_scraped','source','name','description','neighborhood_overview','picture_url','host_url','host_name','host_since','host_location','host_about'], axis=1)
df4
# Out:
#              ï»¿id     scrape_id    host_id host_response_time  \
# 0     9.580000e+02  2.020000e+13       1169                NaN
# 1     5.858000e+03  2.020000e+13       8904                NaN
# 2     8.142000e+03  2.020000e+13      21994                NaN
# 3     8.339000e+03  2.020000e+13      24215                NaN
# 4     8.739000e+03  2.020000e+13       7149                NaN
# ...            ...           ...        ...                ...
# 6931  8.180000e+17  2.020000e+13  495900269                NaN
# 6932  8.180000e+17  2.020000e+13  499392537                NaN
# 6933  8.180000e+17  2.020000e+13  499294716                NaN
# 6934  8.180000e+17  2.020000e+13  485596413                NaN
# 6935  8.190000e+17  2.020000e+13    4836128                NaN
#
#      host_response_rate host_acceptance_rate host_is_superhost  \
# 0                   NaN                  NaN               NaN
# 1                   NaN                  NaN               NaN
# ...

# %%
#Corroboramos valores nulos del dataframe4
valores_nulos=df4.isnull().sum()
valores_nulos
# Out:
# ï»¿id                                              0
# scrape_id                                          0
# host_id                                            0
# host_response_time                              6936
# host_response_rate                              6936
#                                                 ...
# calculated_host_listings_count                   292
# calculated_host_listings_count_entire_homes      292
# calculated_host_listings_count_private_rooms     236
# calculated_host_listings_count_shared_rooms       52
# reviews_per_month                                 98
# Length: 63, dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=df4.copy()
data_clean=df.fillna(round(df.mean(),1))
data_clean
# Out:
# <ipython-input-47-27aa3082b298>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_clean=df.fillna(round(df.mean(),1))
#              ï»¿id                                      listing_url  \
# 0     9.580000e+02                 https://www.airbnb.com/rooms/958
# 1     5.858000e+03                https://www.airbnb.com/rooms/5858
# 2     8.142000e+03                https://www.airbnb.com/rooms/8142
# 3     8.339000e+03                https://www.airbnb.com/rooms/8339
# 4     8.739000e+03                https://www.airbnb.com/rooms/8739
# ...            ...                                              ...
# 6931  8.180000e+17  https://www.airbnb.com/rooms/818195233784141985
# 6932  8.180000e+17  https://www.airbnb.com/rooms/818231243893035313
# ...

# %% [markdown]
# Se utilizó este método con el propósito de que los datos faltantes, sean reemplazados por datos "reales" o que si sea probable que estén y no muestre más valores atípicos.

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# ï»¿id                                           0
# listing_url                                     0
# scrape_id                                       0
# last_scraped                                    0
# source                                          0
#                                                ..
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# Length: 75, dtype: int64

# %%
data_clean.to_csv("Evaluación1_EUA.csv")
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Evaluación1_EUA.csv")
