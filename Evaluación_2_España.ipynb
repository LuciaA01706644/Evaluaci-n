# %% [markdown]
# # Evaluación 2 España
#
# ## Lucía Castañeda A01706644

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carga desde un archivo .xlsx sin indice
df= pd.read_csv('Evaluación1_España.csv')
df
# Out:
# <ipython-input-7-454b165e6b33>:2: DtypeWarning: Columns (0,1,3,10,36,45,46,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv('Evaluación1_España.csv')
#       Unnamed: 0                    id  \
# 0              0                 14551
# 1              1               1205757
# 2              2               1212820
# 3              3                751638
# 4              4                 41342
# ...          ...                   ...
# 19651      19650  858000000000000000.0
# 19652      19651  858000000000000000.0
# 19653      19652  858000000000000000.0
# 19654      19653  858000000000000000.0
# 19655      19654  858000000000000000.0
#
#                                            listing_url         scrape_id  \
# 0                   https://www.airbnb.com/rooms/14551          2.02E+13
# 1                 https://www.airbnb.com/rooms/1205757          2.02E+13
# ...

# %% [markdown]
# ### Filtro 1

# %%
df["host_acceptance_rate"]= df["host_acceptance_rate"].astype(float)

# %%
#host_acceptance_rate> 50%
filtro1= df[df["host_acceptance_rate"] > 50]
filtro1
# Out:
#       Unnamed: 0                    id  \
# 0              0                 14551
# 2              2               1212820
# 3              3                751638
# 5              5                751997
# 6              6                752035
# ...          ...                   ...
# 19648      19647  858000000000000000.0
# 19649      19648  858000000000000000.0
# 19651      19650  858000000000000000.0
# 19652      19651  858000000000000000.0
# 19654      19653  858000000000000000.0
#
#                                            listing_url         scrape_id  \
# 0                   https://www.airbnb.com/rooms/14551          2.02E+13
# 2                 https://www.airbnb.com/rooms/1212820          2.02E+13
# 3                  https://www.airbnb.com/rooms/751638          2.02E+13
# 5                  https://www.airbnb.com/rooms/751997          2.02E+13
# 6                  https://www.airbnb.com/rooms/752035          2.02E+13
# ...

# %% [markdown]
# ### Filtro 2

# %%
# Sólo los registros con categoría “superhost”
filtro2= df[df["host_is_superhost"] == "t"]
filtro2
# Out:
#       Unnamed: 0                    id  \
# 0              0                 14551
# 8              8                 45400
# 10            10                753604
# 21            21                106704
# 23            23                766763
# ...          ...                   ...
# 19598      19597  857000000000000000.0
# 19602      19601  856000000000000000.0
# 19618      19617  857000000000000000.0
# 19629      19628  858000000000000000.0
# 19652      19651  858000000000000000.0
#
#                                            listing_url         scrape_id  \
# 0                   https://www.airbnb.com/rooms/14551          2.02E+13
# 8                   https://www.airbnb.com/rooms/45400          2.02E+13
# 10                 https://www.airbnb.com/rooms/753604          2.02E+13
# 21                 https://www.airbnb.com/rooms/106704          2.02E+13
# 23                 https://www.airbnb.com/rooms/766763          2.02E+13
# ...

# %% [markdown]
# ### Filtro 3

# %%
#Los registros que no hallan verificado identidad "host_identity_verified”
filtro3= df[df["host_identity_verified"] == "f"]
filtro3
# Out:
#       Unnamed: 0                    id  \
# 2              2               1212820
# 7              7               1215790
# 9              9               1222762
# 30            30                784892
# 33            33               1242933
# ...          ...                   ...
# 19554      19553  856000000000000000.0
# 19561      19560  856000000000000000.0
# 19562      19561  856000000000000000.0
# 19612      19611  857000000000000000.0
# 19613      19612  857000000000000000.0
#
#                                            listing_url         scrape_id  \
# 2                 https://www.airbnb.com/rooms/1212820          2.02E+13
# 7                 https://www.airbnb.com/rooms/1215790          2.02E+13
# 9                 https://www.airbnb.com/rooms/1222762          2.02E+13
# 30                 https://www.airbnb.com/rooms/784892          2.02E+13
# 33                https://www.airbnb.com/rooms/1242933          2.02E+13
# ...

# %% [markdown]
# ### Filtro 4

# %%
#Los registro cuyo property_type = “Private room” y “Hotel room”
filtro4=df[(df["property_type"] == "Private room") |(df["property_type"] == "Hotel room")]
filtro4
# Out:
#       Unnamed: 0                    id  \
# 356          356               3054347
# 2485        2484              14613107
# 3135        3134              17117682
# 7839        7838              32997174
# 16666      16665  658000000000000000.0
# 17058      17057  687000000000000000.0
# 19023      19022  841000000000000000.0
#
#                                            listing_url         scrape_id  \
# 356               https://www.airbnb.com/rooms/3054347          2.02E+13
# 2485             https://www.airbnb.com/rooms/14613107          2.02E+13
# 3135             https://www.airbnb.com/rooms/17117682          2.02E+13
# 7839             https://www.airbnb.com/rooms/32997174          2.02E+13
# 16666  https://www.airbnb.com/rooms/658304684608776381  20200000000000.0
# 17058  https://www.airbnb.com/rooms/686737674628035786  20200000000000.0
# 19023  https://www.airbnb.com/rooms/841208789516756655  20200000000000.0
#
#       last_scraped           source  \
# ...

# %% [markdown]
# ### Filtro 5

# %%
# Los registros que cuenten con bathroom > 1
filtro5=df[(df['bathrooms'] > '1' )]
filtro5
# Out:
#                      Unnamed: 0                  id listing_url scrape_id  \
# 1295  Passionate photographer.   within a few hours        100%      100%
#
#      last_scraped                                             source  \
# 1295            f  https://a0.muscache.com/im/users/34733512/prof...
#
#                                                    name description  \
# 1295  https://a0.muscache.com/im/users/34733512/prof...         NaN
#
#      neighborhood_overview picture_url  ... review_scores_communication  \
# 1295                     1           1  ...                         NaN
#
#      review_scores_location review_scores_value license instant_bookable  \
# 1295                    NaN                 NaN     NaN              NaN
#
#      calculated_host_listings_count  \
# 1295                            NaN
#
#      calculated_host_listings_count_entire_homes  \
# 1295                                         NaN
#
#      calculated_host_listings_count_private_rooms  \
# ...

# %% [markdown]
# ### Filtro 6

# %%
#Los registros cuyo precio sea mayor de $10,000 y que sean de tipo “Entire home”
filtro6=df[(df["price"] > 10000) & (df["property_type"] == "Entire home")]
filtro6
# Out:
#     Unnamed: 0       id                           listing_url scrape_id  \
# 753        753  4682669  https://www.airbnb.com/rooms/4682669  2.02E+13
#
#     last_scraped       source         name  \
# 753     01/04/23  city scrape  Rural house
#
#                                            description neighborhood_overview  \
# 753  Rural house (Only Adults) with sustainability ...                   NaN
#
#                                            picture_url  ...  \
# 753  https://a0.muscache.com/pictures/miso/Hosting-...  ...
#
#     review_scores_communication review_scores_location review_scores_value  \
# 753                         5.0                    5.0                 5.0
#
#        license instant_bookable calculated_host_listings_count  \
# 753  PG-000878                f                            2.0
#
#     calculated_host_listings_count_entire_homes  \
# 753                                         2.0
#
#     calculated_host_listings_count_private_rooms  \
# ...

# %% [markdown]
# ### Filtro 7

# %%
# Los registros cuyo review_scores_cleanliness > 4.5
filtro7=df[(df["review_scores_cleanliness"] > 4.5 )]
filtro7
# Out:
#       Unnamed: 0                    id  \
# 0              0                 14551
# 1              1               1205757
# 4              4                 41342
# 5              5                751997
# 6              6                752035
# ...          ...                   ...
# 18962      18961  833000000000000000.0
# 19002      19001  841000000000000000.0
# 19047      19046  842000000000000000.0
# 19078      19077  842000000000000000.0
# 19203      19202  843000000000000000.0
#
#                                            listing_url         scrape_id  \
# 0                   https://www.airbnb.com/rooms/14551          2.02E+13
# 1                 https://www.airbnb.com/rooms/1205757          2.02E+13
# 4                   https://www.airbnb.com/rooms/41342          2.02E+13
# 5                  https://www.airbnb.com/rooms/751997          2.02E+13
# 6                  https://www.airbnb.com/rooms/752035          2.02E+13
# ...

# %% [markdown]
# ### Filtro 8

# %%
# Los registros cuyo review_scores_value > 4.9
filtro8=df[(df["review_scores_value"] > 4.9 )]
filtro8
# Out:
#       Unnamed: 0                    id  \
# 22            22               1234785
# 26            26                774371
# 40            40               1250062
# 43            43                809136
# 53            53               1262051
# ...          ...                   ...
# 19039      19038  841000000000000000.0
# 19047      19046  842000000000000000.0
# 19078      19077  842000000000000000.0
# 19203      19202  843000000000000000.0
# 19468      19467  850000000000000000.0
#
#                                            listing_url         scrape_id  \
# 22                https://www.airbnb.com/rooms/1234785          2.02E+13
# 26                 https://www.airbnb.com/rooms/774371          2.02E+13
# 40                https://www.airbnb.com/rooms/1250062          2.02E+13
# 43                 https://www.airbnb.com/rooms/809136          2.02E+13
# 53                https://www.airbnb.com/rooms/1262051          2.02E+13
# ...

# %% [markdown]
# ### Filtro 9

# %%
df["availability_365"]= df["availability_365"].astype(float)

# %%
# Los registros cuya availability_365< 100
filtro9=df[df['availability_365'] < 100 ]
filtro9
# Out:
#       Unnamed: 0                    id  \
# 4              4                 41342
# 7              7               1215790
# 11            11                 48764
# 15            15                 93343
# 20            20               1234784
# ...          ...                   ...
# 19628      19627  858000000000000000.0
# 19633      19632  858000000000000000.0
# 19635      19634  858000000000000000.0
# 19639      19638  858000000000000000.0
# 19655      19654  858000000000000000.0
#
#                                            listing_url         scrape_id  \
# 4                   https://www.airbnb.com/rooms/41342          2.02E+13
# 7                 https://www.airbnb.com/rooms/1215790          2.02E+13
# 11                  https://www.airbnb.com/rooms/48764          2.02E+13
# 15                  https://www.airbnb.com/rooms/93343          2.02E+13
# 20                https://www.airbnb.com/rooms/1234784          2.02E+13
# ...

# %% [markdown]
# ### Filtro 10

# %%
 # Los registros cuya host_response_time sea “within an hour”
filtro10=df[(df["host_response_time"] == "within an hour" )]
filtro10
# Out:
#       Unnamed: 0                    id  \
# 0              0                 14551
# 5              5                751997
# 6              6                752035
# 8              8                 45400
# 10            10                753604
# ...          ...                   ...
# 19648      19647  858000000000000000.0
# 19649      19648  858000000000000000.0
# 19651      19650  858000000000000000.0
# 19652      19651  858000000000000000.0
# 19654      19653  858000000000000000.0
#
#                                            listing_url         scrape_id  \
# 0                   https://www.airbnb.com/rooms/14551          2.02E+13
# 5                  https://www.airbnb.com/rooms/751997          2.02E+13
# 6                  https://www.airbnb.com/rooms/752035          2.02E+13
# 8                   https://www.airbnb.com/rooms/45400          2.02E+13
# 10                 https://www.airbnb.com/rooms/753604          2.02E+13
# ...

# %%
filtro1.to_csv("Filtro1_ES.csv")
from google.colab import files 
  
  
files.download("Filtro1_ES.csv")

# %%
filtro2.to_csv("Filtro2_ES.csv")
from google.colab import files 
  
  
files.download("Filtro2_ES.csv")

# %%
filtro3.to_csv("Filtro3_ES.csv")
from google.colab import files 
  
  
files.download("Filtro3_ES.csv")

# %%
filtro4.to_csv("Filtro4_ES.csv")
from google.colab import files 
  
  
files.download("Filtro4_ES.csv")

# %%
filtro5.to_csv("Filtro5_ES.csv")
from google.colab import files 
  
  
files.download("Filtro5_ES.csv")

# %%
filtro6.to_csv("Filtro6_ES.csv")
from google.colab import files 
  
  
files.download("Filtro6_ES.csv")

# %%
filtro7.to_csv("Filtro7_ES.csv")
from google.colab import files 
  
  
files.download("Filtro7_ES.csv")

# %%
filtro8.to_csv("Filtro8_ES.csv")
from google.colab import files 
  
  
files.download("Filtro8_ES.csv")

# %%
filtro9.to_csv("Filtro9_ES.csv")
from google.colab import files 
  
  
files.download("Filtro9_ES.csv")

# %%
filtro10.to_csv("Filtro10_ES.csv")
from google.colab import files 
  
  
files.download("Filtro10_ES.csv")
