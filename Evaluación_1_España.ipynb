# %% [markdown]
# # Evaluación 1 España
#
# ## Lucía Castañeda A01706644

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .xlsx sin indice
df= pd.read_csv('Girona_España.csv', encoding = "unicode_escape")
df
# Out:
#                  id                                      listing_url  \
# 0      1.455100e+04               https://www.airbnb.com/rooms/14551
# 1      1.205757e+06             https://www.airbnb.com/rooms/1205757
# 2      1.212820e+06             https://www.airbnb.com/rooms/1212820
# 3      7.516380e+05              https://www.airbnb.com/rooms/751638
# 4      4.134200e+04               https://www.airbnb.com/rooms/41342
# ...             ...                                              ...
# 19650  8.583870e+17  https://www.airbnb.com/rooms/858386613168601750
# 19651  8.583960e+17  https://www.airbnb.com/rooms/858396134121337855
# 19652  8.584110e+17  https://www.airbnb.com/rooms/858410917126332945
# 19653  8.584180e+17  https://www.airbnb.com/rooms/858418062773719271
# 19654  8.584240e+17  https://www.airbnb.com/rooms/858424461046143986
#
#           scrape_id last_scraped           source  \
# 0      2.023030e+13   31/03/2023      city scrape
# 1      2.023030e+13   31/03/2023      city scrape
# 2      2.023030e+13   01/04/2023      city scrape
# 3      2.023030e+13   31/03/2023      city scrape
# 4      2.023030e+13   01/04/2023  previous scrape
# ...             ...          ...              ...
# 19650  2.023030e+13   01/04/2023      city scrape
# 19651  2.023030e+13   01/04/2023      city scrape
# 19652  2.023030e+13   01/04/2023      city scrape
# 19653  2.023030e+13   01/04/2023      city scrape
# 19654  2.023030e+13   01/04/2023      city scrape
#
#                                            name  \
# 0      Cozy & Colorful by Nature (Private Room)
# 1           HabitaciÃ³n doble + baÃ±o y terraza
# 2           Apartment port de rei stunning wiew
# 3           Room Limon - Casa Pati de lÂ´Albera
# 4             Beachfront Tamariua (Costa Brava)
# ...                                         ...
# 19650      Casa La Chumbera, Begur, Costa Brava
# 19651                         Playa a 2 minutos
# 19652                     Apartamento cÃ©ntrico
# 19653    Apto a 5 min de la playa, Platja d'Aro
# 19654                 Apartamento frontal a mar
#
#                                              description  \
# 0      Up in the hill of MontjuÃ¯c (a mountain overlo...
# 1      <b>The space</b><br />HabitaciÃ³n confortable ...
# 2      <b>The space</b><br />Apartments first line un...
# 3      <b>The space</b><br />Nice room with 2 individ...
# 4      A little paradise by the sea. Apartment 2/4 ad...
# ...                                                  ...
# 19650  Individual house located at the urbanization '...
# 19651  MagnÃ­fico piso para pasar vacaciones,dispone ...
# 19652  EstÃ¡ compuesto de dos habitaciones, una de ma...
# 19653  Cozy apartment for 4 people. Perfect to spend ...
# 19654  EstÃ¡ compuesto de tres habitaciones, dos habi...
#
#                                    neighborhood_overview  \
# 0      MontjuÃ¯c is most likely the best neighborhood...
# 1      Bonitas playas a 15 minutos en coche. Piscina ...
# 2                                                    NaN
# 3      Sant Climent is a tiny village, with a populat...
# 4      Apartment located outside the town on a small ...
# ...                                                  ...
# 19650                                                NaN
# 19651                                                NaN
# 19652                                                NaN
# 19653                                                NaN
# 19654                                                NaN
#
#                                              picture_url    host_id  ...  \
# 0      https://a0.muscache.com/pictures/16209908/f1fe...      57237  ...
# 1      https://a0.muscache.com/pictures/02e0a61e-078e...    6586355  ...
# 2      https://a0.muscache.com/pictures/18245529/0886...    6620645  ...
# 3      https://a0.muscache.com/pictures/64276178/98d1...    3680160  ...
# 4      https://a0.muscache.com/pictures/70414801/59d4...     180072  ...
# ...                                                  ...        ...  ...
# 19650  https://a0.muscache.com/pictures/prohost-api/H...   26281633  ...
# 19651  https://a0.muscache.com/pictures/6351279f-294b...  444428600  ...
# 19652  https://a0.muscache.com/pictures/miso/Hosting-...  491503593  ...
# 19653  https://a0.muscache.com/pictures/prohost-api/H...  389605038  ...
# 19654  https://a0.muscache.com/pictures/miso/Hosting-...  491503593  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            4.91                   4.63                4.74
# 1                            4.91                   4.69                4.80
# 2                            4.76                   4.74                4.32
# 3                            5.00                   4.63                4.50
# 4                            4.73                   4.91                4.36
# ...                           ...                    ...                 ...
# 19650                         NaN                    NaN                 NaN
# 19651                         NaN                    NaN                 NaN
# 19652                         NaN                    NaN                 NaN
# 19653                         NaN                    NaN                 NaN
# 19654                         NaN                    NaN                 NaN
#
#            license instant_bookable calculated_host_listings_count  \
# 0      HUTG-049542                f                              1
# 1              NaN                f                              1
# 2              NaN                f                              2
# 3         PG000794                t                              6
# 4      HUTG-003688                f                              1
# ...            ...              ...                            ...
# 19650  HUTG-001292                t                             34
# 19651   HUTG019727                t                              1
# 19652  HUTG-057830                f                              9
# 19653  HUTG-065236                t                             54
# 19654  HUTG-051787                f                              9
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               0
# 1                                               0
# 2                                               2
# 3                                               1
# 4                                               1
# ...                                           ...
# 19650                                          34
# 19651                                           1
# 19652                                           9
# 19653                                          54
# 19654                                           9
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                1
# 1                                                1
# 2                                                0
# 3                                                5
# 4                                                0
# ...                                            ...
# 19650                                            0
# 19651                                            0
# 19652                                            0
# 19653                                            0
# 19654                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.37
# 1                                               0              0.51
# 2                                               0              0.62
# 3                                               0              0.08
# 4                                               0              0.09
# ...                                           ...               ...
# 19650                                           0               NaN
# 19651                                           0               NaN
# 19652                                           0               NaN
# 19653                                           0               NaN
# 19654                                           0               NaN
#
# [19655 rows x 75 columns]

# %%
#Reemplazamos valores nulos del dataframe con "bfill"
df1 =df.fillna(method="bfill") 
df1

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=df1.isnull().sum()
valores_nulos
# Out:
# id                                                0
# listing_url                                       0
# scrape_id                                         0
# last_scraped                                      0
# source                                            0
#                                                ...
# calculated_host_listings_count                    0
# calculated_host_listings_count_entire_homes       0
# calculated_host_listings_count_private_rooms      0
# calculated_host_listings_count_shared_rooms       0
# reviews_per_month                               187
# Length: 75, dtype: int64

# %%
#Reemplazamos valores nulos del dataframe con "mean"
#Realizamos una copia del dataframe
df2=df.copy()
df2=df2.fillna(round(df.mean(),1))
df2

# %%
#Corroboramos valores nulos del dataframe
valores_nulos=df2.isnull().sum()
valores_nulos
# Out:
# id                                              0
# listing_url                                     0
# scrape_id                                       0
# last_scraped                                    0
# source                                          0
#                                                ..
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# Length: 75, dtype: int64

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
df2.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=df2
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# <ipython-input-10-f35936a59650>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# <ipython-input-10-f35936a59650>:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Superior= y.mean() + 3*y.std()
# Limite superior permitido id                                              1.145731e+18
# scrape_id                                       2.023030e+13
# host_id                                         5.776010e+08
# host_listings_count                             5.024385e+02
# host_total_listings_count                       1.304143e+03
# neighbourhood_group_cleansed                             NaN
# latitude                                        4.269221e+01
# longitude                                       3.796862e+00
# accommodates                                    1.357642e+01
# bathrooms                                                NaN
# bedrooms                                        6.642892e+00
# beds                                            1.131747e+01
# minimum_nights                                  6.165308e+01
# maximum_nights                                  2.126503e+03
# minimum_minimum_nights                          3.376590e+01
# maximum_minimum_nights                          8.979748e+01
# minimum_maximum_nights                          2.150761e+03
# maximum_maximum_nights                          2.153433e+03
# minimum_nights_avg_ntm                          4.942393e+01
# maximum_nights_avg_ntm                          2.094086e+03
# calendar_updated                                         NaN
# availability_30                                 5.065433e+01
# availability_60                                 1.028997e+02
# availability_90                                 1.500436e+02
# availability_365                                5.290134e+02
# number_of_reviews                               1.194857e+02
# number_of_reviews_ltm                           3.067935e+01
# number_of_reviews_l30d                          2.102141e+00
# review_scores_rating                            6.116309e+00
# review_scores_accuracy                          5.972786e+00
# review_scores_cleanliness                       6.036924e+00
# review_scores_checkin                           6.017244e+00
# review_scores_communication                     6.019035e+00
# review_scores_location                          5.805032e+00
# review_scores_value                             5.950521e+00
# calculated_host_listings_count                  2.506332e+02
# calculated_host_listings_count_entire_homes     2.425119e+02
# calculated_host_listings_count_private_rooms    1.151000e+01
# calculated_host_listings_count_shared_rooms     8.080682e-01
# reviews_per_month                               2.455846e+00
# dtype: float64
# Limite inferior permitido id                                             -7.620646e+17
# scrape_id                                       2.023030e+13
# host_id                                        -2.629530e+08
# host_listings_count                            -3.736141e+02
# host_total_listings_count                      -1.063956e+03
# neighbourhood_group_cleansed                             NaN
# latitude                                        4.135556e+01
# longitude                                       2.211745e+00
# accommodates                                   -2.493137e+00
# bathrooms                                                NaN
# bedrooms                                       -1.643401e+00
# beds                                           -3.369776e+00
# minimum_nights                                 -5.401899e+01
# maximum_nights                                 -8.076700e+02
# minimum_minimum_nights                         -2.725201e+01
# maximum_minimum_nights                         -7.570194e+01
# minimum_maximum_nights                         -8.980984e+02
# maximum_maximum_nights                         -5.975378e+02
# minimum_nights_avg_ntm                         -4.027011e+01
# maximum_nights_avg_ntm                         -6.268616e+02
# calendar_updated                                         NaN
# availability_30                                -2.022207e+01
# availability_60                                -3.518901e+01
# availability_90                                -4.426360e+01
# availability_365                               -1.456577e+02
# number_of_reviews                              -8.940840e+01
# number_of_reviews_ltm                          -2.196482e+01
# number_of_reviews_l30d                         -1.802675e+00
# review_scores_rating                            3.016488e+00
# review_scores_accuracy                          3.292337e+00
# review_scores_cleanliness                       3.032231e+00
# review_scores_checkin                           3.384625e+00
# review_scores_communication                     3.400714e+00
# review_scores_location                          3.628324e+00
# review_scores_value                             2.918669e+00
# calculated_host_listings_count                 -1.727335e+02
# calculated_host_listings_count_entire_homes    -1.667810e+02
# calculated_host_listings_count_private_rooms   -9.536355e+00
# calculated_host_listings_count_shared_rooms    -7.738784e-01
# reviews_per_month                              -1.421786e+00
# dtype: float64
# <ipython-input-10-f35936a59650>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Inferior= y.mean() - 3*y.std()
# <ipython-input-10-f35936a59650>:4: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Limite_Inferior= y.mean() - 3*y.std()

# %% [markdown]
# Se utilizó este método para eliminar valores atípicos debido a que es menos senisble y ayuda a mantener la forma general de los datos.

# %%
#Encontramos Ouliers del Dataframe
outliers= df2[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# <ipython-input-11-e84a43168787>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers= df2[(y>Limite_Superior)|(y<Limite_Inferior)]
#        id listing_url  scrape_id last_scraped source name description  \
# 0     NaN         NaN        NaN          NaN    NaN  NaN         NaN
# 1     NaN         NaN        NaN          NaN    NaN  NaN         NaN
# 2     NaN         NaN        NaN          NaN    NaN  NaN         NaN
# 3     NaN         NaN        NaN          NaN    NaN  NaN         NaN
# 4     NaN         NaN        NaN          NaN    NaN  NaN         NaN
# ...    ..         ...        ...          ...    ...  ...         ...
# 19650 NaN         NaN        NaN          NaN    NaN  NaN         NaN
# 19651 NaN         NaN        NaN          NaN    NaN  NaN         NaN
# 19652 NaN         NaN        NaN          NaN    NaN  NaN         NaN
# 19653 NaN         NaN        NaN          NaN    NaN  NaN         NaN
# 19654 NaN         NaN        NaN          NaN    NaN  NaN         NaN
#
#       neighborhood_overview picture_url  host_id  ...  \
# 0                       NaN         NaN      NaN  ...
# 1                       NaN         NaN      NaN  ...
# 2                       NaN         NaN      NaN  ...
# 3                       NaN         NaN      NaN  ...
# 4                       NaN         NaN      NaN  ...
# ...                     ...         ...      ...  ...
# 19650                   NaN         NaN      NaN  ...
# 19651                   NaN         NaN      NaN  ...
# 19652                   NaN         NaN      NaN  ...
# 19653                   NaN         NaN      NaN  ...
# 19654                   NaN         NaN      NaN  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                             NaN                    NaN                 NaN
# 1                             NaN                    NaN                 NaN
# 2                             NaN                    NaN                 NaN
# 3                             NaN                    NaN                 NaN
# 4                             NaN                    NaN                 NaN
# ...                           ...                    ...                 ...
# 19650                         NaN                    NaN                 NaN
# 19651                         NaN                    NaN                 NaN
# 19652                         NaN                    NaN                 NaN
# 19653                         NaN                    NaN                 NaN
# 19654                         NaN                    NaN                 NaN
#
#       license instant_bookable calculated_host_listings_count  \
# 0         NaN              NaN                            NaN
# 1         NaN              NaN                            NaN
# 2         NaN              NaN                            NaN
# 3         NaN              NaN                            NaN
# 4         NaN              NaN                            NaN
# ...       ...              ...                            ...
# 19650     NaN              NaN                            NaN
# 19651     NaN              NaN                            NaN
# 19652     NaN              NaN                            NaN
# 19653     NaN              NaN                            NaN
# 19654     NaN              NaN                            NaN
#
#       calculated_host_listings_count_entire_homes  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 19650                                         NaN
# 19651                                         NaN
# 19652                                         NaN
# 19653                                         NaN
# 19654                                         NaN
#
#       calculated_host_listings_count_private_rooms  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 19650                                          NaN
# 19651                                          NaN
# 19652                                          NaN
# 19653                                          NaN
# 19654                                          NaN
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                             NaN               NaN
# 1                                             NaN               NaN
# 2                                             NaN               NaN
# 3                                             NaN               NaN
# 4                                             NaN               NaN
# ...                                           ...               ...
# 19650                                         NaN               NaN
# 19651                                         NaN               NaN
# 19652                                         NaN               NaN
# 19653                                         NaN               NaN
# 19654                                         NaN               NaN
#
# [19655 rows x 75 columns]

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
df3= df2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
df3
# Out:
# <ipython-input-12-0ce5b7a1dcd6>:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df3= df2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
#                  id listing_url     scrape_id last_scraped source name  \
# 0      1.455100e+04         NaN  2.023030e+13          NaN    NaN  NaN
# 1      1.205757e+06         NaN  2.023030e+13          NaN    NaN  NaN
# 2      1.212820e+06         NaN  2.023030e+13          NaN    NaN  NaN
# 3      7.516380e+05         NaN  2.023030e+13          NaN    NaN  NaN
# 4      4.134200e+04         NaN  2.023030e+13          NaN    NaN  NaN
# ...             ...         ...           ...          ...    ...  ...
# 19650  8.583870e+17         NaN  2.023030e+13          NaN    NaN  NaN
# 19651  8.583960e+17         NaN  2.023030e+13          NaN    NaN  NaN
# 19652  8.584110e+17         NaN  2.023030e+13          NaN    NaN  NaN
# 19653  8.584180e+17         NaN  2.023030e+13          NaN    NaN  NaN
# 19654  8.584240e+17         NaN  2.023030e+13          NaN    NaN  NaN
#
#       description neighborhood_overview picture_url    host_id  ...  \
# 0             NaN                   NaN         NaN      57237  ...
# 1             NaN                   NaN         NaN    6586355  ...
# 2             NaN                   NaN         NaN    6620645  ...
# 3             NaN                   NaN         NaN    3680160  ...
# 4             NaN                   NaN         NaN     180072  ...
# ...           ...                   ...         ...        ...  ...
# 19650         NaN                   NaN         NaN   26281633  ...
# 19651         NaN                   NaN         NaN  444428600  ...
# 19652         NaN                   NaN         NaN  491503593  ...
# 19653         NaN                   NaN         NaN  389605038  ...
# 19654         NaN                   NaN         NaN  491503593  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            4.91                   4.63                4.74
# 1                            4.91                   4.69                4.80
# 2                            4.76                   4.74                4.32
# 3                            5.00                   4.63                4.50
# 4                            4.73                   4.91                4.36
# ...                           ...                    ...                 ...
# 19650                        4.70                   4.70                4.40
# 19651                        4.70                   4.70                4.40
# 19652                        4.70                   4.70                4.40
# 19653                        4.70                   4.70                4.40
# 19654                        4.70                   4.70                4.40
#
#       license instant_bookable calculated_host_listings_count  \
# 0         NaN              NaN                            1.0
# 1         NaN              NaN                            1.0
# 2         NaN              NaN                            2.0
# 3         NaN              NaN                            6.0
# 4         NaN              NaN                            1.0
# ...       ...              ...                            ...
# 19650     NaN              NaN                           34.0
# 19651     NaN              NaN                            1.0
# 19652     NaN              NaN                            9.0
# 19653     NaN              NaN                           54.0
# 19654     NaN              NaN                            9.0
#
#       calculated_host_listings_count_entire_homes  \
# 0                                             0.0
# 1                                             0.0
# 2                                             2.0
# 3                                             1.0
# 4                                             1.0
# ...                                           ...
# 19650                                        34.0
# 19651                                         1.0
# 19652                                         9.0
# 19653                                        54.0
# 19654                                         9.0
#
#       calculated_host_listings_count_private_rooms  \
# 0                                              1.0
# 1                                              1.0
# 2                                              0.0
# 3                                              5.0
# 4                                              0.0
# ...                                            ...
# 19650                                          0.0
# 19651                                          0.0
# 19652                                          0.0
# 19653                                          0.0
# 19654                                          0.0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                             0.0              0.37
# 1                                             0.0              0.51
# 2                                             0.0              0.62
# 3                                             0.0              0.08
# 4                                             0.0              0.09
# ...                                           ...               ...
# 19650                                         0.0              0.50
# 19651                                         0.0              0.50
# 19652                                         0.0              0.50
# 19653                                         0.0              0.50
# 19654                                         0.0              0.50
#
# [19655 rows x 75 columns]

# %%
#Eliminamos columnas innecesarias
df4= df3.drop(['listing_url','last_scraped','source'], axis=1)
df4
# Out:
#                  id     scrape_id name description neighborhood_overview  \
# 0      1.455100e+04  2.023030e+13  NaN         NaN                   NaN
# 1      1.205757e+06  2.023030e+13  NaN         NaN                   NaN
# 2      1.212820e+06  2.023030e+13  NaN         NaN                   NaN
# 3      7.516380e+05  2.023030e+13  NaN         NaN                   NaN
# 4      4.134200e+04  2.023030e+13  NaN         NaN                   NaN
# ...             ...           ...  ...         ...                   ...
# 19650  8.583870e+17  2.023030e+13  NaN         NaN                   NaN
# 19651  8.583960e+17  2.023030e+13  NaN         NaN                   NaN
# 19652  8.584110e+17  2.023030e+13  NaN         NaN                   NaN
# 19653  8.584180e+17  2.023030e+13  NaN         NaN                   NaN
# 19654  8.584240e+17  2.023030e+13  NaN         NaN                   NaN
#
#       picture_url    host_id host_url host_name host_since  ...  \
# 0             NaN      57237      NaN       NaN        NaN  ...
# 1             NaN    6586355      NaN       NaN        NaN  ...
# 2             NaN    6620645      NaN       NaN        NaN  ...
# 3             NaN    3680160      NaN       NaN        NaN  ...
# 4             NaN     180072      NaN       NaN        NaN  ...
# ...           ...        ...      ...       ...        ...  ...
# 19650         NaN   26281633      NaN       NaN        NaN  ...
# 19651         NaN  444428600      NaN       NaN        NaN  ...
# 19652         NaN  491503593      NaN       NaN        NaN  ...
# 19653         NaN  389605038      NaN       NaN        NaN  ...
# 19654         NaN  491503593      NaN       NaN        NaN  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            4.91                   4.63                4.74
# 1                            4.91                   4.69                4.80
# 2                            4.76                   4.74                4.32
# 3                            5.00                   4.63                4.50
# 4                            4.73                   4.91                4.36
# ...                           ...                    ...                 ...
# 19650                        4.70                   4.70                4.40
# 19651                        4.70                   4.70                4.40
# 19652                        4.70                   4.70                4.40
# 19653                        4.70                   4.70                4.40
# 19654                        4.70                   4.70                4.40
#
#       license instant_bookable calculated_host_listings_count  \
# 0         NaN              NaN                            1.0
# 1         NaN              NaN                            1.0
# 2         NaN              NaN                            2.0
# 3         NaN              NaN                            6.0
# 4         NaN              NaN                            1.0
# ...       ...              ...                            ...
# 19650     NaN              NaN                           34.0
# 19651     NaN              NaN                            1.0
# 19652     NaN              NaN                            9.0
# 19653     NaN              NaN                           54.0
# 19654     NaN              NaN                            9.0
#
#       calculated_host_listings_count_entire_homes  \
# 0                                             0.0
# 1                                             0.0
# 2                                             2.0
# 3                                             1.0
# 4                                             1.0
# ...                                           ...
# 19650                                        34.0
# 19651                                         1.0
# 19652                                         9.0
# 19653                                        54.0
# 19654                                         9.0
#
#       calculated_host_listings_count_private_rooms  \
# 0                                              1.0
# 1                                              1.0
# 2                                              0.0
# 3                                              5.0
# 4                                              0.0
# ...                                            ...
# 19650                                          0.0
# 19651                                          0.0
# 19652                                          0.0
# 19653                                          0.0
# 19654                                          0.0
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                             0.0               0.37
# 1                                             0.0               0.51
# 2                                             0.0               0.62
# 3                                             0.0               0.08
# 4                                             0.0               0.09
# ...                                           ...                ...
# 19650                                         0.0               0.50
# 19651                                         0.0               0.50
# 19652                                         0.0               0.50
# 19653                                         0.0               0.50
# 19654                                         0.0               0.50
#
# [19655 rows x 72 columns]

# %%
#Corroboramos valores nulos del dataframe4
valores_nulos=df4.isnull().sum()
valores_nulos
# Out:
# id                                                  0
# scrape_id                                           0
# name                                            19655
# description                                     19655
# neighborhood_overview                           19655
#                                                 ...
# calculated_host_listings_count                    405
# calculated_host_listings_count_entire_homes       405
# calculated_host_listings_count_private_rooms      671
# calculated_host_listings_count_shared_rooms       181
# reviews_per_month                                 414
# Length: 72, dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=df4.copy()
data_clean=df.fillna(round(df.mean(),1))
data_clean
# Out:
# <ipython-input-15-27aa3082b298>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_clean=df.fillna(round(df.mean(),1))
#                  id                                      listing_url  \
# 0      1.455100e+04               https://www.airbnb.com/rooms/14551
# 1      1.205757e+06             https://www.airbnb.com/rooms/1205757
# 2      1.212820e+06             https://www.airbnb.com/rooms/1212820
# 3      7.516380e+05              https://www.airbnb.com/rooms/751638
# 4      4.134200e+04               https://www.airbnb.com/rooms/41342
# ...             ...                                              ...
# 19650  8.583870e+17  https://www.airbnb.com/rooms/858386613168601750
# 19651  8.583960e+17  https://www.airbnb.com/rooms/858396134121337855
# 19652  8.584110e+17  https://www.airbnb.com/rooms/858410917126332945
# 19653  8.584180e+17  https://www.airbnb.com/rooms/858418062773719271
# 19654  8.584240e+17  https://www.airbnb.com/rooms/858424461046143986
#
#           scrape_id last_scraped           source  \
# 0      2.023030e+13   31/03/2023      city scrape
# 1      2.023030e+13   31/03/2023      city scrape
# 2      2.023030e+13   01/04/2023      city scrape
# 3      2.023030e+13   31/03/2023      city scrape
# 4      2.023030e+13   01/04/2023  previous scrape
# ...             ...          ...              ...
# 19650  2.023030e+13   01/04/2023      city scrape
# 19651  2.023030e+13   01/04/2023      city scrape
# 19652  2.023030e+13   01/04/2023      city scrape
# 19653  2.023030e+13   01/04/2023      city scrape
# 19654  2.023030e+13   01/04/2023      city scrape
#
#                                            name  \
# 0      Cozy & Colorful by Nature (Private Room)
# 1           HabitaciÃ³n doble + baÃ±o y terraza
# 2           Apartment port de rei stunning wiew
# 3           Room Limon - Casa Pati de lÂ´Albera
# 4             Beachfront Tamariua (Costa Brava)
# ...                                         ...
# 19650      Casa La Chumbera, Begur, Costa Brava
# 19651                         Playa a 2 minutos
# 19652                     Apartamento cÃ©ntrico
# 19653    Apto a 5 min de la playa, Platja d'Aro
# 19654                 Apartamento frontal a mar
#
#                                              description  \
# 0      Up in the hill of MontjuÃ¯c (a mountain overlo...
# 1      <b>The space</b><br />HabitaciÃ³n confortable ...
# 2      <b>The space</b><br />Apartments first line un...
# 3      <b>The space</b><br />Nice room with 2 individ...
# 4      A little paradise by the sea. Apartment 2/4 ad...
# ...                                                  ...
# 19650  Individual house located at the urbanization '...
# 19651  MagnÃ­fico piso para pasar vacaciones,dispone ...
# 19652  EstÃ¡ compuesto de dos habitaciones, una de ma...
# 19653  Cozy apartment for 4 people. Perfect to spend ...
# 19654  EstÃ¡ compuesto de tres habitaciones, dos habi...
#
#                                    neighborhood_overview  \
# 0      MontjuÃ¯c is most likely the best neighborhood...
# 1      Bonitas playas a 15 minutos en coche. Piscina ...
# 2                                                    NaN
# 3      Sant Climent is a tiny village, with a populat...
# 4      Apartment located outside the town on a small ...
# ...                                                  ...
# 19650                                                NaN
# 19651                                                NaN
# 19652                                                NaN
# 19653                                                NaN
# 19654                                                NaN
#
#                                              picture_url    host_id  ...  \
# 0      https://a0.muscache.com/pictures/16209908/f1fe...      57237  ...
# 1      https://a0.muscache.com/pictures/02e0a61e-078e...    6586355  ...
# 2      https://a0.muscache.com/pictures/18245529/0886...    6620645  ...
# 3      https://a0.muscache.com/pictures/64276178/98d1...    3680160  ...
# 4      https://a0.muscache.com/pictures/70414801/59d4...     180072  ...
# ...                                                  ...        ...  ...
# 19650  https://a0.muscache.com/pictures/prohost-api/H...   26281633  ...
# 19651  https://a0.muscache.com/pictures/6351279f-294b...  444428600  ...
# 19652  https://a0.muscache.com/pictures/miso/Hosting-...  491503593  ...
# 19653  https://a0.muscache.com/pictures/prohost-api/H...  389605038  ...
# 19654  https://a0.muscache.com/pictures/miso/Hosting-...  491503593  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            4.91                   4.63                4.74
# 1                            4.91                   4.69                4.80
# 2                            4.76                   4.74                4.32
# 3                            5.00                   4.63                4.50
# 4                            4.73                   4.91                4.36
# ...                           ...                    ...                 ...
# 19650                        4.70                   4.70                4.40
# 19651                        4.70                   4.70                4.40
# 19652                        4.70                   4.70                4.40
# 19653                        4.70                   4.70                4.40
# 19654                        4.70                   4.70                4.40
#
#            license instant_bookable calculated_host_listings_count  \
# 0      HUTG-049542                f                              1
# 1              NaN                f                              1
# 2              NaN                f                              2
# 3         PG000794                t                              6
# 4      HUTG-003688                f                              1
# ...            ...              ...                            ...
# 19650  HUTG-001292                t                             34
# 19651   HUTG019727                t                              1
# 19652  HUTG-057830                f                              9
# 19653  HUTG-065236                t                             54
# 19654  HUTG-051787                f                              9
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               0
# 1                                               0
# 2                                               2
# 3                                               1
# 4                                               1
# ...                                           ...
# 19650                                          34
# 19651                                           1
# 19652                                           9
# 19653                                          54
# 19654                                           9
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                1
# 1                                                1
# 2                                                0
# 3                                                5
# 4                                                0
# ...                                            ...
# 19650                                            0
# 19651                                            0
# 19652                                            0
# 19653                                            0
# 19654                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              0.37
# 1                                               0              0.51
# 2                                               0              0.62
# 3                                               0              0.08
# 4                                               0              0.09
# ...                                           ...               ...
# 19650                                           0              0.50
# 19651                                           0              0.50
# 19652                                           0              0.50
# 19653                                           0              0.50
# 19654                                           0              0.50
#
# [19655 rows x 75 columns]

# %% [markdown]
# Se utilizó este método con el propósito de que los datos faltantes, sean reemplazados por datos "reales" o que si sea probable que estén y no muestre más valores atípicos.

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# id                                              0
# listing_url                                     0
# scrape_id                                       0
# last_scraped                                    0
# source                                          0
#                                                ..
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# Length: 75, dtype: int64

# %%
data_clean.to_csv("Evaluación1_España.csv")
#descargar archivo filtrado en csv
from google.colab import files 
  
  
files.download("Evaluación1_España.csv")
